# %%
# %load_ext autoreload

# %%
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import yaml
import json
import os
from flatten_dict import unflatten, flatten
from filter_utils import *
from pandas.api.types import is_numeric_dtype
import seaborn as sns
from sklearn.preprocessing import minmax_scale, LabelEncoder




import multiprocessing as mp
print("Number of processors: ", mp.cpu_count())
os.getcwd()
# Out:
# Number of processors:  8
# '/Users/morarica/Developer/SepMe/Jupyters'

# %% [markdown]
# ## 1. Getting the human annotations

# %%
def underscore_reducer(k1, k2):
    if k1 is None:
        return str(k2)
    else:
        return str(k1) + "_" + str(k2)

# %%
folder = '/Users/morarica/Developer/SepMe/data/SPLOM_data/SepMe/Data/Human_judgment/'
print(len(sorted(os.listdir(folder))))
df_a = []
df_m = []
for i, file in enumerate(sorted(os.listdir(folder))):
    if file.endswith('csv'):
        #print(file)
        df = pd.read_csv(folder+file, header=None)
        df.columns = np.array(df.columns)+1
        
        if len(df)>4:
            #print(df)
            df = df.head(4)
        
        df.index = ['PCA', 'RobPCA', 'GlimmerMDS', 'tSNE']
        
        person = file.split('.csv')[0].split('-')[-1]
        dd ={}
        dd[file.split('-')[0]] = df.to_dict('index')
        df1 = pd.DataFrame.from_dict(flatten(dd, underscore_reducer), orient='index', columns = [person])
        
        #print(person + '  ' + file)
        if person =='M':
            df_m.append(df1)
        else:
            df_a.append(df1)

dfmm = pd.concat(df_m, axis=0)
dfaa = pd.concat(df_a, axis=0)

df = pd.concat([dfmm, dfaa], axis=1)


df['class'] = [ii.split('_')[-1] for ii in df.index]
df.dropna(axis=0, inplace=True)

df = df.astype({'A': 'int32', 'M': 'int32'})
print(df.shape)
# Out:
# 153
# (1669, 3)

# %%
df['dim_x'] = 1
df['dim_y'] = 2
df = df[df.A.between(1,5) & df.M.between(1,5)]
df = df.reset_index()
print(df.shape)
df.head()


names = ['_'.join(row.split('_')[:-1]) for row in list(df['index'])]
#names = list(set(names))

df['fileName'] = names
# Out:
# (1648, 6)

# %%
df.to_csv('/Users/morarica/Developer/SepMe/data/orig_data/human_reduced_results.csv', index=False)

# %% [markdown]
# ## 2. Plot inputs

# %%
def remove_outlier(df, dims = [.05,.95]):
    low = dims[0]
    high = dims[1]
    quant_df = df.quantile([low, high])
    #print(quant_df)
    for name in list(df.columns):
        if name in ['x','y']:
            df = df[(df[name] > quant_df.loc[low, name]) 
               & (df[name] < quant_df.loc[high, name])]
        #print(len(df))
    return df

def preprocess_df(df, dims, size = 0.5, occlusion = 0.1, save=None, sort=True):
    
    ddf = df[dims + ['class']].copy()
    #print(ddf.head())
    
    #print(ddf.shape)
    classes = list(set(ddf['class']))
    if len(classes)>10:
        print('Classes: {}'.format(len(classes)))
        ddf.columns = ['x', 'y', 'orig_class'] #rename cols
        merge_classes = list(ddf[['orig_class', 'x']].groupby(['orig_class']).count()
                             .sort_values(['x'], ascending=True).head(len(classes)-9).index)
        
        ddf['class'] = [row if row not in merge_classes else -1 for i,row in ddf['orig_class'].items()]
        
        le = LabelEncoder()
        ddf['class'] = le.fit_transform(ddf['class'])
        
    else: 
        ddf.columns = ['x', 'y', 'class'] #rename cols
        le = LabelEncoder()
        ddf['orig_class'] = ddf['class']
        ddf['class'] = le.fit_transform(ddf['orig_class'])
        
        
    ddf = remove_outlier(ddf, [0.05, 0.95]) #remove outliers
    ddf.iloc[:,:2] = minmax_scale(ddf.iloc[:, :2]) #scale between 0 and 1
    
    if sort == True:
        ddf = ddf.sort_values(['x', 'y']) # sort
        
    #print(ddf.shape)   
    
    ddf.reset_index(inplace=True, drop=True) #reset_index 
    
    # filter occluded circles
    buff = ((max(ddf.x) - min(ddf.x)) / (np.sqrt(len(ddf.x))*2))*size
    circles = get_circles(ddf, buff)
    rem_indexes = remove_circles_by_partition(ddf, circles, 2*buff, occlusion)
    ddf = ddf.drop(rem_indexes)
    circles = circles.drop(rem_indexes)
    
    if save is not None:
        ddf.to_csv(save, index=False)
    
    return ddf, circles


def plot_colored_circles(ax, df, circles, class_name = 'class'):
    
    for i, row in df.iterrows():
        ax.add_patch(PolygonPatch(circles[i], fc = sns.color_palette("colorblind")[int(row[class_name])], ec = 'none', alpha = 1))
            
    ax.autoscale()
    ax.set_aspect('equal', 'datalim')

    return ax

def get_dimred_data(df, input_folder, save_folder, fig_folder):
    found = 0
    not_found = []
    names = ['_'.join(row.split('_')[:-1]) for row in list(df['index'])]
    names = list(set(names))
    
    for i, nn in enumerate(names):
        
        print('Processing file {}/{}. Name: {}'.format(i, len(names), nn))
        
        method = nn.split('_')[-1]
        #print(method)
        if method in {'PCA', 'RobPCA'}:
            name = nn + '_data.csv'
        else: 
            name = nn + '_2.csv'
            
        #print(name)
            
        try:
            data = pd.read_csv(input_folder+method+'/'+name)
            found += 1
            
            dim_x = str(df.loc[i, 'dim_x'])
            dim_y = str(df.loc[i, 'dim_y'])
            
            file_name = save_folder + nn + '_' + dim_x +'-' + dim_y +'.csv'
            
            if os.path.exists(file_name) is True:
                print('File was already processed. Skipping: {}'.format(file_name))
                continue

            ddf, circles = preprocess_df(data, [dim_x, dim_y], size = 0.5, occlusion = 0.1, save=file_name, sort=True)


            fig, ax = plt.subplots(figsize = (10,10))
            plot_colored_circles(ax, ddf, circles)
            fig.savefig(fig_folder + names[i] + '.pdf')
            plt.close('all')


        except FileNotFoundError:
            #print(nn)
            print('File not found: {}'.format(name))
            not_found.append(name)
            
    return

# %%
input_folder = '/Users/morarica/Developer/SepMe/data/orig_data/input_data/Reduced_orig_data/'
save_folder = '/Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/'
fig_folder = '/Users/morarica/Developer/SepMe/data/orig_data/figures/reduced_data/'

get_dimred_data(df, input_folder, save_folder, fig_folder)
# Out:
# Processing file 0/216. Name: boston_GlimmerMDS
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/boston_GlimmerMDS_1-2.csv
# Processing file 1/216. Name: bbdm13_GlimmerMDS
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/bbdm13_GlimmerMDS_1-2.csv
# Processing file 2/216. Name: cars03Cropped_d3_RobPCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/cars03Cropped_d3_RobPCA_1-2.csv
# Processing file 3/216. Name: ms_interleaved_120_240_3d_25_centeredClusters_tSNE
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/ms_interleaved
PCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/fisheries_clusteredByEscapementTarget_PCA_1-2.csv
# Processing file 180/216. Name: interleaved_100_200_10d_25_cramped_rotated_GlimmerMDS
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/interleaved_100_200_10d_25_cramped_rotated_GlimmerMDS_1-2.csv
# Processing file 181/216. Name: ionosphere_tSNE
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/ionosphere_tSNE_1-2.csv
# Processing file 182/216. Name: twosquare_PCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/twosquare_PCA_1-2.csv
# Processing file 183/216. Name: ms_interleaved_120_240_3d_50_centeredClusters_tSNE
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/ms_interleaved_120_240_3d_50_centeredClusters_tSNE_1-2.csv
# Processing file 184/216. Name: grid6_4d_PCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/grid6_4d_PCA_1-2.csv
# Processing file 185/216. Name: n500_tSNE
# File not found: n500_tSNE_2.csv
# Processing file 186/216. Name: cars03Cropped_d1_GlimmerMDS
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/cars03Cropped_d1_GlimmerMDS_1-2.csv
# Processing file 187/216. Name: JavierGeneratedData_3dinterleaved_4classes_tSNE
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/JavierGeneratedData_3dinterleaved_4classes_tSNE_1-2.csv
# Processing file 188/216. Name: JavierGeneratedData_3dinterleaved_4classes_RobPCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/JavierGeneratedData_3dinterleaved_4classes_RobPCA_1-2.csv
# Processing file 189/216. Name: interleaved_250_500_3_0_notCramped_rotated_RobPCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/interleaved_250_500_3_0_notCramped_rotated_RobPCA_1-2.csv
# Processing file 190/216. Name: wine_tSNE
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/wine_tSNE_1-2.csv
# Processing file 191/216. Name: parkinsons_abs_croped_RobPCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/parkinsons_abs_croped_RobPCA_1-2.csv
# Processing file 192/216. Name: fisheries_clusteredByEscapementTarget_tSNE
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/fisheries_clusteredByEscapementTarget_tSNE_1-2.csv
# Processing file 193/216. Name: interleaved_250_500_3_0_notCramped_rotated_GlimmerMDS
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/interleaved_250_500_3_0_notCramped_rotated_GlimmerMDS_1-2.csv
# Processing file 194/216. Name: fisheries_clusteredByHarvestRule_GlimmerMDS
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/fisheries_clusteredByHarvestRule_GlimmerMDS_1-2.csv
# Processing file 195/216. Name: ms_interleaved_120_240_3d_25_centeredClusters_PCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/ms_interleaved_120_240_3d_25_centeredClusters_PCA_1-2.csv
# Processing file 196/216. Name: twosquare_GlimmerMDS
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/twosquare_GlimmerMDS_1-2.csv
# Processing file 197/216. Name: boston_PCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/boston_PCA_1-2.csv
# Processing file 198/216. Name: musicnetgroups_tSNE
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/musicnetgroups_tSNE_1-2.csv
# Processing file 199/216. Name: white_ballance_GlimmerMDS
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/white_ballance_GlimmerMDS_1-2.csv
# Processing file 200/216. Name: ionosphere_PCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/ionosphere_PCA_1-2.csv
# Processing file 201/216. Name: ms_interleaved_40_80_3d_50_GlimmerMDS
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/ms_interleaved_40_80_3d_50_GlimmerMDS_1-2.csv
# Processing file 202/216. Name: ms_interleaved_60_120_3d_0_centeredClusters_RobPCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/ms_interleaved_60_120_3d_0_centeredClusters_RobPCA_1-2.csv
# Processing file 203/216. Name: interleaved_100_200_10d_25_cramped_rotated_tSNE
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/interleaved_100_200_10d_25_cramped_rotated_tSNE_1-2.csv
# Processing file 204/216. Name: cars03Cropped_d2_RobPCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/cars03Cropped_d2_RobPCA_1-2.csv
# Processing file 205/216. Name: interleaved_100_200_15d_0_notcramped_notrotated_GlimmerMDS
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/interleaved_100_200_15d_0_notcramped_notrotated_GlimmerMDS_1-2.csv
# Processing file 206/216. Name: world_11d_RobPCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/world_11d_RobPCA_1-2.csv
# Processing file 207/216. Name: olive_RobPCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/olive_RobPCA_1-2.csv
# Processing file 208/216. Name: interleaved_100_200_15d_0_notcramped_notrotated_tSNE
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/interleaved_100_200_15d_0_notcramped_notrotated_tSNE_1-2.csv
# Processing file 209/216. Name: interleaved_250_500_3_0_notCramped_rotated_tSNE
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/interleaved_250_500_3_0_notCramped_rotated_tSNE_1-2.csv
# Processing file 210/216. Name: wdbc_class_1_2_tSNE
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/wdbc_class_1_2_tSNE_1-2.csv
# Processing file 211/216. Name: italianwines_RobPCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/italianwines_RobPCA_1-2.csv
# Processing file 212/216. Name: worldmap_GlimmerMDS
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/worldmap_GlimmerMDS_1-2.csv
# Processing file 213/216. Name: grid10_3d_tSNE
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/grid10_3d_tSNE_1-2.csv
# Processing file 214/216. Name: cars03Cropped_d1_RobPCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/cars03Cropped_d1_RobPCA_1-2.csv
# Processing file 215/216. Name: grid10_3d_PCA
# File was already processed. Skipping: /Users/morarica/Developer/SepMe/data/orig_data/input_data/reduced_clean/grid10_3d_PCA_1-2.csv

# %% [markdown]
# ## 3. Plot dimensions in original data

# %%
def save_and_plot_all_dimensions(orig_dir, save_dir, fig_dir, class_cols):
    for i, file in enumerate(os.listdir(orig_dir)):
        if file.endswith('.csv'):
            print('Processing file {}/{}. Name: {}'.format(i, len(os.listdir(orig_dir)), file))
            if file in ['shuttle_small_origClassLabels.csv', 'shuttle_big.csv']:
                continue
            
            df = pd.read_csv(orig_dir + file)

            c1s = []
            for c1 in df.columns:
                if not np.issubdtype(df[c1].dtype, np.number) or (c1 in class_cols):
                    continue

                c1s.append(c1)
                for c2 in df.columns[:-1]:
                    if (not np.issubdtype(df[c1].dtype, np.number)) or (c2 in c1s) or (c2 in class_cols):
                        continue

                    file_name = save_dir + file.split('.csv')[0] + '_{}-{}'.format(c1,c2) + '.csv'
                    fig_name = fig_dir + file.split('.csv')[0] + '_{}-{}'.format(c1,c2) + '.pdf'
                    
                    if os.path.exists(file_name) is True:
                        print('File was already processed. Skipping: {}'.format(file_name.split('/')[-1]))
                        continue

                    try: 
                        print('{}-{}'.format(c1,c2))
                        ddf, circles = preprocess_df(df, [c1, c2], size = 0.5, 
                                                 occlusion = 0.1, save=file_name, sort=True)
                        fig, ax = plt.subplots(figsize = (10,10))
                        plot_colored_circles(ax, ddf, circles)
                        fig.savefig(fig_name)
                        plt.close('all')
                        
                    except Exception as e: 
                        print('File {} was not processed for columns ({},{}).'.format(file,c1,c2))
                        print(e)
                        print('')

# %%
orig_dir = "/Users/morarica/Developer/SepMe/data/orig_data/input_data/Orig_data/"
save_dir = "/Users/morarica/Developer/SepMe/data/orig_data/input_data/dims_clean/"
fig_dir = "/Users/morarica/Developer/SepMe/data/orig_data/figures/orig_dim_data/"
class_cols = ['class']

save_and_plot_all_dimensions(orig_dir, save_dir, fig_dir, class_cols)
# Out:
# Processing file 0/104. Name: grid10_3d.csv
# File was already processed. Skipping: grid10_3d_d1-d2.csv
# File was already processed. Skipping: grid10_3d_d1-d3.csv
# File was already processed. Skipping: grid10_3d_d2-d3.csv
# Processing file 1/104. Name: interleaved_100_200_4d_0_notcramped_notrotated.csv
# File was already processed. Skipping: interleaved_100_200_4d_0_notcramped_notrotated_d1-d2.csv
# File was already processed. Skipping: interleaved_100_200_4d_0_notcramped_notrotated_d1-d3.csv
# File was already processed. Skipping: interleaved_100_200_4d_0_notcramped_notrotated_d1-d4.csv
# File was already processed. Skipping: interleaved_100_200_4d_0_notcramped_notrotated_d2-d3.csv
# File was already processed. Skipping: interleaved_100_200_4d_0_notcramped_notrotated_d2-d4.csv
# File was already processed. Skipping: interleaved_100_200_4d_0_notcramped_notrotated_d3-d4.csv
# Processing file 2/104. Name: abalone.csv
# File was already processed. Skipping: abalone_x1-x2.csv
# File was already processed. Skipping: abalone_x1-x3.csv
# File was already processed. Skipping: abalone_x1-x4.csv
# File was already processed. Skipping: abalone_x1-x5.csv
# File was already processed. Skipping: abalone_x1-x6.csv
# File was already processed. Skipping: abalone_x1-x7.csv
# File was already processed. Skipping: abalone_x2-x3.csv
# File was already processed. Skipping: abalone_x2-x4.csv
# File was already processed. Skipping: abalone_x2-x5.csv
# File was already processed. Skipping: abalone_x2-x6.csv
# File was already processed. Skipping: abalone_x2-x7.csv
# File was already processed. Skipping: abalone_x3-x4.csv
# File was already processed. Skipping: abalone_x3-x5.csv
# File was already processed. Skipping: abalone_x3-x6.csv
# File was already processed. Skipping: abalone_x3-x7.csv
# File was already processed. Skipping: abalone_x4-x5.csv
# File was already processed. Skipping: abalone_x4-x6.csv
# File was already processed. Skipping: abalone_x4-x7.csv
# File was already processed. Skipping: abalone_x5-x6.csv
# File was already processed. Skipping: abalone_x5-x7.csv
# File was already processed. Skipping: abalone_x6-x7.csv
# Processing file 3/104. Name: n100-d5-c3-spr0.1-out0.csv
# File was already processed. Skipping: n100-d5-c3-spr0.1-out0_D1-D2.csv
# File was already processed. Skipping: n100-d5-c3-spr0.1-out0_D1-D3.csv
# File was already processed. Skipping: n100-d5-c3-spr0.1-out0_D1-D4.csv
# File was already processed. Skipping: n100-d5-c3-spr0.1-out0_D1-D5.csv
# File was already processed. Skipping: n100-d5-c3-spr0.1-out0_D2-D3.csv
# File was already processed. Skipping: n100-d5-c3-spr0.1-out0_D2-D4.csv
# File was already processed. Skipping: n100-d5-c3-spr0.1-out0_D2-D5.csv
# File was already processed. Skipping: n100-d5-c3-spr0.1-out0_D3-D4.csv
# File was already processed. Skipping: n100-d5-c3-spr0.1-out0_D3-D5.csv
# File was already processed. Skipping: n100-d5-c3-spr0.1-out0_D4-D5.csv
# Processing file 4/104. Name: ms_interleaved_60_120_3d_0_centeredClusters.csv
# File was already processed. Skipping: ms_interleaved_60_120_3d_0_centeredClusters_d1-d2.csv
# File was already processed. Skipping: ms_interleaved_60_120_3d_0_centeredClusters_d1-d3.csv
# File was already processed. Skipping: ms_interleaved_60_120_3d_0_centeredClusters_d2-d3.csv
# Processing file 5/104. Name: efashion.csv
# year-d2
# File efashion.csv was not processed for columns (year,d2).
# float division by zero
#
# year-d3
# File efashion.csv was not processed for columns (year,d3).
# float division by zero
#
# year-d4
# File efashion.csv was not processed for columns (year,d4).
# float division by zero
#
# File was already processed. Skipping: efashion_d2-d3.csv
# File was already processed. Skipping: efashion_d2-d4.csv
# File was already processed. Skipping: efashion_d3-d4.csv
# Processing file 6/104. Name: UnEvenDensity.csv
# Col1-Col2
# File UnEvenDensity.csv was not processed for columns (Col1,Col2).
# "['class'] not in index"
#
# Col1-Col3
# File UnEvenDensity.csv was not processed for columns (Col1,Col3).
# "['class'] not in index"
#
# Col1-Class
# File UnEvenDensity.csv was not processed for columns (Col1,Class).
# "['class'] not in index"
#
# Col2-Col3
# File UnEvenDensity.csv was not processed for columns (Col2,Col3).
# "['class'] not in index"
#
# Col2-Class
# File UnEvenDensity.csv was not processed for columns (Col2,Class).
# "['class'] not in index"
#
# Col3-Class
# File UnEvenDensity.csv was not processed for columns (Col3,Class).
# "['class'] not in index"
#
# Processing file 7/104. Name: ionosphere.csv
# D1-D2
# File ionosphere.csv was not processed for columns (D1,D2).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D3
# File ionosphere.csv was not processed for columns (D1,D3).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D4
# File ionosphere.csv was not processed for columns (D1,D4).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D5
# File ionosphere.csv was not processed for columns (D1,D5).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D6
# File ionosphere.csv was not processed for columns (D1,D6).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D7
# File ionosphere.csv was not processed for columns (D1,D7).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D8
# File ionosphere.csv was not processed for columns (D1,D8).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D9
# File ionosphere.csv was not processed for columns (D1,D9).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D10
# File ionosphere.csv was not processed for columns (D1,D10).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D11
# File ionosphere.csv was not processed for columns (D1,D11).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D12
# File ionosphere.csv was not processed for columns (D1,D12).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D13
# File ionosphere.csv was not processed for columns (D1,D13).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D14
# File ionosphere.csv was not processed for columns (D1,D14).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D15
# File ionosphere.csv was not processed for columns (D1,D15).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D16
# File ionosphere.csv was not processed for columns (D1,D16).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D17
# File ionosphere.csv was not processed for columns (D1,D17).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D18
# File ionosphere.csv was not processed for columns (D1,D18).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D19
# File ionosphere.csv was not processed for columns (D1,D19).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D20
# File ionosphere.csv was not processed for columns (D1,D20).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D21
# File ionosphere.csv was not processed for columns (D1,D21).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D22
# File ionosphere.csv was not processed for columns (D1,D22).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D23
# File ionosphere.csv was not processed for columns (D1,D23).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D24
# File ionosphere.csv was not processed for columns (D1,D24).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D25
# File ionosphere.csv was not processed for columns (D1,D25).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D26
# File ionosphere.csv was not processed for columns (D1,D26).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D27
# File ionosphere.csv was not processed for columns (D1,D27).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D28
# File ionosphere.csv was not processed for columns (D1,D28).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D29
# File ionosphere.csv was not processed for columns (D1,D29).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D30
# File ionosphere.csv was not processed for columns (D1,D30).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D31
# File ionosphere.csv was not processed for columns (D1,D31).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D32
# File ionosphere.csv was not processed for columns (D1,D32).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D33
# File ionosphere.csv was not processed for columns (D1,D33).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D1-D34
# File ionosphere.csv was not processed for columns (D1,D34).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D3
# File ionosphere.csv was not processed for columns (D2,D3).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D4
# File ionosphere.csv was not processed for columns (D2,D4).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D5
# File ionosphere.csv was not processed for columns (D2,D5).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D6
# File ionosphere.csv was not processed for columns (D2,D6).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D7
# File ionosphere.csv was not processed for columns (D2,D7).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D8
# File ionosphere.csv was not processed for columns (D2,D8).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D9
# File ionosphere.csv was not processed for columns (D2,D9).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D10
# File ionosphere.csv was not processed for columns (D2,D10).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D11
# File ionosphere.csv was not processed for columns (D2,D11).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D12
# File ionosphere.csv was not processed for columns (D2,D12).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D13
# File ionosphere.csv was not processed for columns (D2,D13).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D14
# File ionosphere.csv was not processed for columns (D2,D14).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D15
# File ionosphere.csv was not processed for columns (D2,D15).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D16
# File ionosphere.csv was not processed for columns (D2,D16).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D17
# File ionosphere.csv was not processed for columns (D2,D17).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D18
# File ionosphere.csv was not processed for columns (D2,D18).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D19
# File ionosphere.csv was not processed for columns (D2,D19).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D20
# File ionosphere.csv was not processed for columns (D2,D20).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D21
# File ionosphere.csv was not processed for columns (D2,D21).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D22
# File ionosphere.csv was not processed for columns (D2,D22).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D23
# File ionosphere.csv was not processed for columns (D2,D23).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D24
# File ionosphere.csv was not processed for columns (D2,D24).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D25
# File ionosphere.csv was not processed for columns (D2,D25).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D26
# File ionosphere.csv was not processed for columns (D2,D26).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D27
# File ionosphere.csv was not processed for columns (D2,D27).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D28
# File ionosphere.csv was not processed for columns (D2,D28).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D29
# File ionosphere.csv was not processed for columns (D2,D29).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D30
# File ionosphere.csv was not processed for columns (D2,D30).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D31
# File ionosphere.csv was not processed for columns (D2,D31).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D32
# File ionosphere.csv was not processed for columns (D2,D32).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D33
# File ionosphere.csv was not processed for columns (D2,D33).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# D2-D34
# File ionosphere.csv was not processed for columns (D2,D34).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# File was already processed. Skipping: ionosphere_D3-D4.csv
# File was already processed. Skipping: ionosphere_D3-D5.csv
# File was already processed. Skipping: ionosphere_D3-D6.csv
# File was already processed. Skipping: ionosphere_D3-D7.csv
# File was already processed. Skipping: ionosphere_D3-D8.csv
# File was already processed. Skipping: ionosphere_D3-D9.csv
# File was already processed. Skipping: ionosphere_D3-D10.csv
# File was already processed. Skipping: ionosphere_D3-D11.csv
# File was already processed. Skipping: ionosphere_D3-D12.csv
# File was already processed. Skipping: ionosphere_D3-D13.csv
# File was already processed. Skipping: ionosphere_D3-D14.csv
# File was already processed. Skipping: ionosphere_D3-D15.csv
# File was already processed. Skipping: ionosphere_D3-D16.csv
# File was already processed. Skipping: ionosphere_D3-D17.csv
# File was already processed. Skipping: ionosphere_D3-D18.csv
# File was already processed. Skipping: ionosphere_D3-D19.csv
# File was already processed. Skipping: ionosphere_D3-D20.csv
# File was already processed. Skipping: ionosphere_D3-D21.csv
# File was already processed. Skipping: ionosphere_D3-D22.csv
# File was already processed. Skipping: ionosphere_D3-D23.csv
# File was already processed. Skipping: ionosphere_D3-D24.csv
# File was already processed. Skipping: ionosphere_D3-D25.csv
# File was already processed. Skipping: ionosphere_D3-D26.csv
# File was already processed. Skipping: ionosphere_D3-D27.csv
# File was already processed. Skipping: ionosphere_D3-D28.csv
# File was already processed. Skipping: ionosphere_D3-D29.csv
# File was already processed. Skipping: ionosphere_D3-D30.csv
# File was already processed. Skipping: ionosphere_D3-D31.csv
# File was already processed. Skipping: ionosphere_D3-D32.csv
# File was already processed. Skipping: ionosphere_D3-D33.csv
# File was already processed. Skipping: ionosphere_D3-D34.csv
# File was already processed. Skipping: ionosphere_D4-D5.csv
# File was already processed. Skipping: ionosphere_D4-D6.csv
# File was already processed. Skipping: ionosphere_D4-D7.csv
# File was already processed. Skipping: ionosphere_D4-D8.csv
# File was already processed. Skipping: ionosphere_D4-D9.csv
# File was already processed. Skipping: ionosphere_D4-D10.csv
# File was already processed. Skipping: ionosphere_D4-D11.csv
# File was already processed. Skipping: ionosphere_D4-D12.csv
# File was already processed. Skipping: ionosphere_D4-D13.csv
# File was already processed. Skipping: ionosphere_D4-D14.csv
# File was already processed. Skipping: ionosphere_D4-D15.csv
# File was already processed. Skipping: ionosphere_D4-D16.csv
# File was already processed. Skipping: ionosphere_D4-D17.csv
# File was already processed. Skipping: ionosphere_D4-D18.csv
# File was already processed. Skipping: ionosphere_D4-D19.csv
# File was already processed. Skipping: ionosphere_D4-D20.csv
# File was already processed. Skipping: ionosphere_D4-D21.csv
# File was already processed. Skipping: ionosphere_D4-D22.csv
# File was already processed. Skipping: ionosphere_D4-D23.csv
# File was already processed. Skipping: ionosphere_D4-D24.csv
# File was already processed. Skipping: ionosphere_D4-D25.csv
# File was already processed. Skipping: ionosphere_D4-D26.csv
# File was already processed. Skipping: ionosphere_D4-D27.csv
# File was already processed. Skipping: ionosphere_D4-D28.csv
# File was already processed. Skipping: ionosphere_D4-D29.csv
# File was already processed. Skipping: ionosphere_D4-D30.csv
# File was already processed. Skipping: ionosphere_D4-D31.csv
# File was already processed. Skipping: ionosphere_D4-D32.csv
# File was already processed. Skipping: ionosphere_D4-D33.csv
# File was already processed. Skipping: ionosphere_D4-D34.csv
# File was already processed. Skipping: ionosphere_D5-D6.csv
# File was already processed. Skipping: ionosphere_D5-D7.csv
# File was already processed. Skipping: ionosphere_D5-D8.csv
# File was already processed. Skipping: ionosphere_D5-D9.csv
# File was already processed. Skipping: ionosphere_D5-D10.csv
# File was already processed. Skipping: ionosphere_D5-D11.csv
# File was already processed. Skipping: ionosphere_D5-D12.csv
# File was already processed. Skipping: ionosphere_D5-D13.csv
# File was already processed. Skipping: ionosphere_D5-D14.csv
# File was already processed. Skipping: ionosphere_D5-D15.csv
# File was already processed. Skipping: ionosphere_D5-D16.csv
# File was already processed. Skipping: ionosphere_D5-D17.csv
# File was already processed. Skipping: ionosphere_D5-D18.csv
# File was already processed. Skipping: ionosphere_D5-D19.csv
# File was already processed. Skipping: ionosphere_D5-D20.csv
# File was already processed. Skipping: ionosphere_D5-D21.csv
# File was already processed. Skipping: ionosphere_D5-D22.csv
# File was already processed. Skipping: ionosphere_D5-D23.csv
# File was already processed. Skipping: ionosphere_D5-D24.csv
# File was already processed. Skipping: ionosphere_D5-D25.csv
# File was already processed. Skipping: ionosphere_D5-D26.csv
# File was already processed. Skipping: ionosphere_D5-D27.csv
# File was already processed. Skipping: ionosphere_D5-D28.csv
# File was already processed. Skipping: ionosphere_D7-D31.csv
# File was already processed. Skipping: ionosphere_D7-D32.csv
# File was already processed. Skipping: ionosphere_D7-D33.csv
# File was already processed. Skipping: ionosphere_D7-D34.csv
# File was already processed. Skipping: ionosphere_D8-D9.csv
# File was already processed. Skipping: ionosphere_D8-D10.csv
# File was already processed. Skipping: ionosphere_D8-D11.csv
# File was already processed. Skipping: ionosphere_D8-D12.csv
# File was already processed. Skipping: ionosphere_D8-D13.csv
# File was already processed. Skipping: ionosphere_D8-D14.csv
# File was already processed. Skipping: ionosphere_D8-D15.csv
# File was already processed. Skipping: ionosphere_D8-D16.csv
# File was already processed. Skipping: ionosphere_D8-D17.csv
# File was already processed. Skipping: ionosphere_D8-D18.csv
# File was already processed. Skipping: ionosphere_D8-D19.csv
# File was already processed. Skipping: ionosphere_D8-D20.csv
# File was already processed. Skipping: ionosphere_D8-D21.csv
# File was already processed. Skipping: ionosphere_D8-D22.csv
# File was already processed. Skipping: ionosphere_D8-D23.csv
# File was already processed. Skipping: ionosphere_D8-D24.csv
# File was already processed. Skipping: ionosphere_D8-D25.csv
# File was already processed. Skipping: ionosphere_D8-D26.csv
# File was already processed. Skipping: ionosphere_D8-D27.csv
# File was already processed. Skipping: ionosphere_D8-D28.csv
# File was already processed. Skipping: ionosphere_D8-D29.csv
# File was already processed. Skipping: ionosphere_D8-D30.csv
# File was already processed. Skipping: ionosphere_D8-D31.csv
# File was already processed. Skipping: ionosphere_D8-D32.csv
# File was already processed. Skipping: ionosphere_D8-D33.csv
# File was already processed. Skipping: ionosphere_D8-D34.csv
# File was already processed. Skipping: ionosphere_D9-D10.csv
# File was already processed. Skipping: ionosphere_D9-D11.csv
# File was already processed. Skipping: ionosphere_D9-D12.csv
# File was already processed. Skipping: ionosphere_D9-D13.csv
# File was already processed. Skipping: ionosphere_D9-D14.csv
# File was already processed. Skipping: ionosphere_D9-D15.csv
# File was already processed. Skipping: ionosphere_D9-D16.csv
# File was already processed. Skipping: ionosphere_D9-D17.csv
# File was already processed. Skipping: ionosphere_D9-D18.csv
# File was already processed. Skipping: ionosphere_D9-D19.csv
# File was already processed. Skipping: ionosphere_D9-D20.csv
# File was already processed. Skipping: ionosphere_D9-D21.csv
# File was already processed. Skipping: ionosphere_D9-D22.csv
# File was already processed. Skipping: ionosphere_D9-D23.csv
# File was already processed. Skipping: ionosphere_D9-D24.csv
# File was already processed. Skipping: ionosphere_D9-D25.csv
# File was already processed. Skipping: ionosphere_D9-D26.csv
# File was already processed. Skipping: ionosphere_D9-D27.csv
# File was already processed. Skipping: ionosphere_D9-D28.csv
# File was already processed. Skipping: ionosphere_D9-D29.csv
# File was already processed. Skipping: ionosphere_D9-D30.csv
# File was already processed. Skipping: ionosphere_D9-D31.csv
# File was already processed. Skipping: ionosphere_D9-D32.csv
# File was already processed. Skipping: ionosphere_D9-D33.csv
# File was already processed. Skipping: ionosphere_D9-D34.csv
# File was already processed. Skipping: ionosphere_D10-D11.csv
# File was already processed. Skipping: ionosphere_D15-D20.csv
# File was already processed. Skipping: ionosphere_D15-D21.csv
# File was already processed. Skipping: ionosphere_D15-D22.csv
# File was already processed. Skipping: ionosphere_D15-D23.csv
# File was already processed. Skipping: ionosphere_D15-D24.csv
# File was already processed. Skipping: ionosphere_D15-D25.csv
# File was already processed. Skipping: ionosphere_D15-D26.csv
# File was already processed. Skipping: ionosphere_D15-D27.csv
# File was already processed. Skipping: ionosphere_D15-D28.csv
# File was already processed. Skipping: ionosphere_D15-D29.csv
# File was already processed. Skipping: ionosphere_D15-D30.csv
# File was already processed. Skipping: ionosphere_D15-D31.csv
# File was already processed. Skipping: ionosphere_D15-D32.csv
# File was already processed. Skipping: ionosphere_D15-D33.csv
# File was already processed. Skipping: ionosphere_D15-D34.csv
# File was already processed. Skipping: ionosphere_D16-D17.csv
# File was already processed. Skipping: ionosphere_D16-D18.csv
# File was already processed. Skipping: ionosphere_D16-D19.csv
# File was already processed. Skipping: ionosphere_D16-D20.csv
# File was already processed. Skipping: ionosphere_D16-D21.csv
# File was already processed. Skipping: ionosphere_D16-D22.csv
# File was already processed. Skipping: ionosphere_D16-D23.csv
# File was already processed. Skipping: ionosphere_D16-D24.csv
# File was already processed. Skipping: ionosphere_D16-D25.csv
# File was already processed. Skipping: ionosphere_D16-D26.csv
# File was already processed. Skipping: ionosphere_D16-D27.csv
# File was already processed. Skipping: ionosphere_D16-D28.csv
# File was already processed. Skipping: ionosphere_D16-D29.csv
# File was already processed. Skipping: ionosphere_D16-D30.csv
# File was already processed. Skipping: ionosphere_D16-D31.csv
# File was already processed. Skipping: ionosphere_D16-D32.csv
# File was already processed. Skipping: ionosphere_D16-D33.csv
# File was already processed. Skipping: ionosphere_D16-D34.csv
# File was already processed. Skipping: ionosphere_D17-D18.csv
# File was already processed. Skipping: ionosphere_D17-D19.csv
# File was already processed. Skipping: ionosphere_D17-D20.csv
# File was already processed. Skipping: ionosphere_D17-D21.csv
# File was already processed. Skipping: ionosphere_D17-D22.csv
# File was already processed. Skipping: ionosphere_D17-D23.csv
# File was already processed. Skipping: ionosphere_D17-D24.csv
# File was already processed. Skipping: ionosphere_D17-D25.csv
# File was already processed. Skipping: ionosphere_D17-D26.csv
# File was already processed. Skipping: ionosphere_D17-D27.csv
# File was already processed. Skipping: ionosphere_D17-D28.csv
# File was already processed. Skipping: ionosphere_D17-D29.csv
# File was already processed. Skipping: ionosphere_D17-D30.csv
# File was already processed. Skipping: ionosphere_D17-D31.csv
# File was already processed. Skipping: ionosphere_D17-D32.csv
# File was already processed. Skipping: ionosphere_D17-D33.csv
# File was already processed. Skipping: ionosphere_D17-D34.csv
# File was already processed. Skipping: ionosphere_D18-D19.csv
# File was already processed. Skipping: ionosphere_D18-D20.csv
# File was already processed. Skipping: ionosphere_D18-D21.csv
# File was already processed. Skipping: ionosphere_D18-D22.csv
# File was already processed. Skipping: ionosphere_D18-D23.csv
# File was already processed. Skipping: ionosphere_D18-D24.csv
# File was already processed. Skipping: ionosphere_D22-D27.csv
# File was already processed. Skipping: ionosphere_D22-D28.csv
# File was already processed. Skipping: ionosphere_D22-D29.csv
# File was already processed. Skipping: ionosphere_D22-D30.csv
# File was already processed. Skipping: ionosphere_D22-D31.csv
# File was already processed. Skipping: ionosphere_D22-D32.csv
# File was already processed. Skipping: ionosphere_D22-D33.csv
# File was already processed. Skipping: ionosphere_D22-D34.csv
# File was already processed. Skipping: ionosphere_D23-D24.csv
# File was already processed. Skipping: ionosphere_D23-D25.csv
# File was already processed. Skipping: ionosphere_D23-D26.csv
# File was already processed. Skipping: ionosphere_D23-D27.csv
# File was already processed. Skipping: ionosphere_D23-D28.csv
# File was already processed. Skipping: ionosphere_D23-D29.csv
# File was already processed. Skipping: ionosphere_D23-D30.csv
# File was already processed. Skipping: ionosphere_D23-D31.csv
# File was already processed. Skipping: ionosphere_D23-D32.csv
# File was already processed. Skipping: ionosphere_D23-D33.csv
# File was already processed. Skipping: ionosphere_D23-D34.csv
# File was already processed. Skipping: ionosphere_D24-D25.csv
# File was already processed. Skipping: ionosphere_D24-D26.csv
# File was already processed. Skipping: ionosphere_D24-D27.csv
# File was already processed. Skipping: ionosphere_D24-D28.csv
# File was already processed. Skipping: ionosphere_D24-D29.csv
# File was already processed. Skipping: ionosphere_D24-D30.csv
# File was already processed. Skipping: ionosphere_D24-D31.csv
# File was already processed. Skipping: ionosphere_D24-D32.csv
# File was already processed. Skipping: ionosphere_D24-D33.csv
# File was already processed. Skipping: ionosphere_D24-D34.csv
# File was already processed. Skipping: ionosphere_D25-D26.csv
# File was already processed. Skipping: ionosphere_D25-D27.csv
# File was already processed. Skipping: ionosphere_D25-D28.csv
# File was already processed. Skipping: ionosphere_D25-D29.csv
# File was already processed. Skipping: ionosphere_D25-D30.csv
# File was already processed. Skipping: ionosphere_D25-D31.csv
# File was already processed. Skipping: ionosphere_D25-D32.csv
# File was already processed. Skipping: ionosphere_D25-D33.csv
# File was already processed. Skipping: ionosphere_D25-D34.csv
# File was already processed. Skipping: ionosphere_D26-D27.csv
# File was already processed. Skipping: ionosphere_D26-D28.csv
# File was already processed. Skipping: ionosphere_D26-D29.csv
# File was already processed. Skipping: ionosphere_D26-D30.csv
# File was already processed. Skipping: ionosphere_D26-D31.csv
# File was already processed. Skipping: ionosphere_D26-D32.csv
# File was already processed. Skipping: ionosphere_D26-D33.csv
# File was already processed. Skipping: ionosphere_D26-D34.csv
# File was already processed. Skipping: ionosphere_D27-D28.csv
# File was already processed. Skipping: ionosphere_D27-D29.csv
# File was already processed. Skipping: ionosphere_D27-D30.csv
# File was already processed. Skipping: ionosphere_D27-D31.csv
# File was already processed. Skipping: ionosphere_D27-D32.csv
# File was already processed. Skipping: ionosphere_D27-D33.csv
# File was already processed. Skipping: ionosphere_D27-D34.csv
# File was already processed. Skipping: ionosphere_D28-D29.csv
# File was already processed. Skipping: ionosphere_D28-D30.csv
# File was already processed. Skipping: ionosphere_D28-D31.csv
# File was already processed. Skipping: ionosphere_D28-D32.csv
# File was already processed. Skipping: ionosphere_D28-D33.csv
# File was already processed. Skipping: ionosphere_D28-D34.csv
# File was already processed. Skipping: ionosphere_D29-D30.csv
# File was already processed. Skipping: ionosphere_D29-D31.csv
# File was already processed. Skipping: ionosphere_D29-D32.csv
# File was already processed. Skipping: ionosphere_D29-D33.csv
# File was already processed. Skipping: ionosphere_D29-D34.csv
# File was already processed. Skipping: ionosphere_D30-D31.csv
# File was already processed. Skipping: ionosphere_D30-D32.csv
# File was already processed. Skipping: ionosphere_D30-D33.csv
# File was already processed. Skipping: ionosphere_D30-D34.csv
# File was already processed. Skipping: ionosphere_D31-D32.csv
# File was already processed. Skipping: ionosphere_D31-D33.csv
# File was already processed. Skipping: ionosphere_D31-D34.csv
# File was already processed. Skipping: ionosphere_D32-D33.csv
# File was already processed. Skipping: ionosphere_D32-D34.csv
# File was already processed. Skipping: ionosphere_D33-D34.csv
# Processing file 8/104. Name: bbdm13_origClassLabels.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V1-V2.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V1-V3.csv
# V1-V4
# File bbdm13_origClassLabels.csv was not processed for columns (V1,V4).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# File was already processed. Skipping: bbdm13_origClassLabels_V1-V5.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V1-V6.csv
# V1-V7
# File bbdm13_origClassLabels.csv was not processed for columns (V1,V7).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# File was already processed. Skipping: bbdm13_origClassLabels_V1-V8.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V1-V9.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V1-V10.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V1-V11.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V1-V12.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V1-V13.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V2-V3.csv
# V2-V4
# File bbdm13_origClassLabels.csv was not processed for columns (V2,V4).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# File was already processed. Skipping: bbdm13_origClassLabels_V2-V5.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V2-V6.csv
# V2-V7
# File bbdm13_origClassLabels.csv was not processed for columns (V2,V7).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# File was already processed. Skipping: bbdm13_origClassLabels_V2-V8.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V2-V9.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V2-V10.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V2-V11.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V2-V12.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V2-V13.csv
# V3-V4
# File bbdm13_origClassLabels.csv was not processed for columns (V3,V4).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# File was already processed. Skipping: bbdm13_origClassLabels_V3-V5.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V3-V6.csv
# V3-V7
# File bbdm13_origClassLabels.csv was not processed for columns (V3,V7).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# File was already processed. Skipping: bbdm13_origClassLabels_V3-V8.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V3-V9.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V3-V10.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V3-V11.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V3-V12.csv
# File was already processed. Skipping: bbdm13_origClassLabels_V3-V13.csv
# V4-V5
# File bbdm13_origClassLabels.csv was not processed for columns (V4,V5).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# V4-V6
# File bbdm13_origClassLabels.csv was not processed for columns (V4,V6).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# V4-V7
# File bbdm13_origClassLabels.csv was not processed for columns (V4,V7).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# V4-V8
# File bbdm13_origClassLabels.csv was not processed for columns (V4,V8).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# V4-V9
# File bbdm13_origClassLabels.csv was not processed for columns (V4,V9).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# V4-V10
# File bbdm13_origClassLabels.csv was not processed for columns (V4,V10).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# V4-V11
# File bbdm13_origClassLabels.csv was not processed for columns (V4,V11).
# Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.
#
# V4-V12
# File bbdm13_origClassLabels.csv was not processed for columns (V4,V12).
# ...
# File was already processed. Skipping: cars03Cropped_d2_d3-d16.csv
# File was already processed. Skipping: cars03Cropped_d2_d3-d17.csv
# File was already processed. Skipping: cars03Cropped_d2_d3-d18.csv
# File was already processed. Skipping: cars03Cropped_d2_d3-d19.1.csv
# File was already processed. Skipping: cars03Cropped_d2_d3-d20.csv
# File was already processed. Skipping: cars03Cropped_d2_d3-d21.csv
# File was already processed. Skipping: cars03Cropped_d2_
# File was already processed. Skipping: shuttle_small_d2-d5.csv
# File was already processed. Skipping: shuttle_small_d2-d6.csv
# File was already processed. Skipping: shuttle_small_d2-d7.csv
# File was already processed. Skipping: shuttle_small_d2-d8.csv
# File was already processed. Skipping: shuttle_small_d2-d9.csv
# File was already processed. Skipping: shuttle_small_d3-d4.csv
# File was already processed. Skipping: shuttle_small_d3-d5.csv
# File was already processed. Skipping: shuttle_small_d3-d6.csv
# File was already processed. Skipping: shuttle_small_d3-d7.csv
# File was already processed. Skipping: shuttle_small_d3-d8.csv
# File was already processed. Skipping: shuttle_small_d3-d9.csv
# File was already processed. Skipping: shuttle_small_d4-d5.csv
# File was already processed. Skipping: shuttle_small_d4-d6.csv
# File was already processed. Skipping: shuttle_small_d4-d7.csv
# File was already processed. Skipping: shuttle_small_d4-d8.csv
# File was already processed. Skipping: shuttle_small_d4-d9.csv
# File was already processed. Skipping: shuttle_small_d5-d6.csv
# File was already processed. Skipping: shuttle_small_d5-d7.csv
# File was already processed. Skipping: shuttle_small_d5-d8.csv
# File was already processed. Skipping: shuttle_small_d5-d9.csv
# File was already processed. Skipping: shuttle_small_d6-d7.csv
# File was already processed. Skipping: shuttle_small_d6-d8.csv
# File was already processed. Skipping: shuttle_small_d6-d9.csv
# File was already processed. Skipping: shuttle_small_d7-d8.csv
# File was already processed. Skipping: shuttle_small_d7-d9.csv
# d8-d9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-2e20b4489115> in <module>
#       4 class_cols = ['class']
#       5
# ----> 6 save_and_plot_all_dimensions(orig_dir, save_dir, fig_dir, class_cols)
#
# <ipython-input-10-51fa82180888> in save_and_plot_all_dimensions(orig_dir, save_dir, fig_dir, class_cols)
#      28                         print('{}-{}'.format(c1,c2))
#      29                         ddf, circles = preprocess_df(df, [c1, c2], size = 0.5,
# ---> 30                                                  occlusion = 0.1, save=file_name, sort=True)
#      31                         fig, ax = plt.subplots(figsize = (10,10))
#      32                         plot_colored_circles(ax, ddf, circles)
#
# <ipython-input-8-0560e77a89e0> in preprocess_df(df, dims, size, occlusion, save, sort)
#      49     buff = ((max(ddf.x) - min(ddf.x)) / (np.sqrt(len(ddf.x))*2))*size
#      50     circles = get_circles(ddf, buff)
# ---> 51     rem_indexes = remove_circles_by_partition(ddf, circles, 2*buff, occlusion)
#      52     ddf = ddf.drop(rem_indexes)
#      53     circles = circles.drop(rem_indexes)
#
# ~/Developer/SepMe/Jupyters/filter_utils.py in remove_circles_by_partition(df, circle_series, n, percent)
#     130         initial_area = cascaded_union(list(temp_circles)).area
#     131
# --> 132         new_area = cascaded_union(list(temp_circles.drop([i]))).area
#     133
#     134         #print((initial_area - new_area) / temp_circles[i].area)
#
# ~/miniconda3/envs/SepMe/lib/python3.7/site-packages/shapely/ops.py in cascaded_union(self, geoms)
#     129             subs[i] = g._geom
#     130         collection = lgeos.GEOSGeom_createCollection(6, subs, L)
# --> 131         return geom_factory(lgeos.methods['cascaded_union'](collection))
#     132
#     133     def unary_union(self, geoms):
#
# KeyboardInterrupt:

# %%
pd.read_csv()
