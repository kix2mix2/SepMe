# %%
# %load_ext autoreload

# %%
# %autoreload 2
# %matplotlib inline
import pandas as pd
import numpy as np
import os
import sys
import matplotlib
import matplotlib.pyplot as plt
from shapely.geometry import Point
from shapely.ops import cascaded_union
from descartes import PolygonPatch, patch
from operator import sub
from sklearn.preprocessing import minmax_scale
from matplotlib.collections import PatchCollection
from sklearn.utils import shuffle
from filter_utils import *

np.seterr(invalid='raise')

data_path = '../data/binary_data/RESULTS_EUROVIS2015.csv'
folder_path = "../data/binary_data/EUROVIS_new/"

df = get_data(5, data_path = data_path, folder_path = folder_path)
buff = (max(df.x) - min(df.x)) / (np.sqrt(len(df.x))*2)

print(buff)
df.head()
# Out:
# 16.04349197777314
#      x    y  class
# 0  121  559      0
# 1  126  504      1
# 2  130  894      0
# 3  135  738      1
# 4  135  745      1

# %%
ddf = shuffle(df).reset_index(drop=True)
ddf.head()
# Out:
#      x    y  class
# 0  301  742      1
# 1  809  649      0
# 2  329  496      1
# 3  541  211      0
# 4  448  411      0

# %%
circles = get_circles(df, buff)
f = plt.figure(figsize = (5, 5))
ax=plt.subplot(1,1,1)
plot_occluded_circles(ax, [circles, circles[circles.index<3]], ['blue', 'red'], [0.3, 1])

# %%
# %%time
f = plt.figure(figsize = (10, 10))
ii = 4
m = 1
p = .25

for i in range(ii):
    ax=plt.subplot(ii/2, 2, i+1)
    

    if i == 0 :
        circle_series = get_circles(df, m*buff)
        
    elif i == 1 :
        circle_series = get_circles(ddf, m*buff)
        
    else :
        circle_series = get_circles(shuffle(df), m*buff)
        
    final_circles, rem_indexes = remove_circles(circle_series, p)
    print("Initial Circles: %3d" %(len(circle_series)))
    print('Final Circles: %3d' %(len(final_circles)))
    print('Indexes: {}'.format(rem_indexes))

    if len(rem_indexes)>0:
        plot_series, colors, alphas = get_plotting_order(circle_series, rem_indexes)
        plot_occluded_circles(ax, plot_series, colors, alphas)
        
    if i != 0 :
        ax.title.set_text('Shuffled Data; Removed circles: {}'.format(len(rem_indexes)))
    else:
        ax.title.set_text('Original Order; Removed circles: {}'.format(len(rem_indexes)))
    
f.savefig('data5_method1_{}buff_{}percent.pdf'.format(m, p))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Developer/SepMe/Jupyters/filter_utils.py in remove_circles(circles, percent)
#      95
#      96
# ---> 97         initial_area = cascaded_union(list(temp_circ)).area
#      98         new_area = cascaded_union(list(temp_circ.drop([i]))).area
#      99         # print('Initial Area: %6.2f; New Area: %6.2f' %(initial_area,new_area))
#
# ~/miniconda3/envs/SepMe/lib/python3.7/site-packages/shapely/ops.py in cascaded_union(self, geoms)
#     129             subs[i] = g._geom
#     130         collection = lgeos.GEOSGeom_createCollection(6, subs, L)
# --> 131         return geom_factory(lgeos.methods['cascaded_union'](collection))
#     132
#     133     def unary_union(self, geoms):
#
# KeyboardInterrupt:

# %%
# %%time
f = plt.figure(figsize = (10, 10))


for i in range(ii):
    ax=plt.subplot(ii/2, 2, i+1)
    

    if i == 0 :
        circle_series = get_circles(df, m*buff)
        final_circles, rem_indexes = remove_circles_by_partition(df, circle_series, 2*buff, .25)
        
    elif i == 1 :
        circle_series = get_circles(ddf, m*buff)
        final_circles, rem_indexes = remove_circles_by_partition(ddf, circle_series, 2*buff, .25)
        
    else :
        etc = shuffle(df).reset_index(drop=True)
        circle_series = get_circles(etc, m*buff)
        final_circles, rem_indexes = remove_circles_by_partition(etc, circle_series, 2*buff, .25)
        
        
    print("Initial Circles: %3d" %(len(circle_series)))
    print('Final Circles: %3d' %(len(final_circles)))
    print('Indexes: {}'.format(rem_indexes))

    if len(rem_indexes)>0:
        plot_series, colors, alphas = get_plotting_order(circle_series, rem_indexes)
        plot_occluded_circles(ax, plot_series, colors, alphas)
        
    if i != 0 :
        ax.title.set_text('Shuffled Data; Removed circles: {}'.format(len(rem_indexes)))
    else:
        ax.title.set_text('Original Order; Removed circles: {}'.format(len(rem_indexes)))





f.savefig('data5_method2_{}buff_{}percent.pdf'.format(m, p))
# Out:
# Initial Circles: 597
# Final Circles: 492
# Indexes: [3, 17, 33, 40, 43, 44, 46, 47, 50, 51, 52, 54, 57, 58, 61, 62, 74, 87, 101, 134, 135, 136, 158, 161, 169, 177, 181, 182, 186, 188, 190, 193, 203, 207, 211, 228, 231, 232, 233, 244, 249, 251, 252, 260, 265, 273, 280, 282, 283, 290, 302, 303, 308, 310, 314, 330, 333, 334, 338, 340, 360, 364, 367, 370, 384, 385, 389, 397, 399, 401, 412, 416, 420, 422, 423, 428, 429, 430, 434, 438, 446, 447, 448, 463, 466, 471, 476, 480, 482, 490, 508, 512, 543, 544, 546, 547, 548, 553, 557, 562, 563, 565, 569, 582, 583]
# Initial Circles: 597
# Final Circles: 445
# Indexes: [5, 6, 8, 9, 10, 14, 16, 20, 21, 23, 26, 27, 33, 34, 35, 36, 39, 41, 42, 45, 48, 50, 55, 56, 57, 58, 59, 60, 62, 64, 66, 67, 68, 72, 75, 77, 78, 79, 80, 81, 82, 84, 85, 86, 88, 93, 94, 95, 98, 99, 100, 106, 111, 112, 113, 114, 120, 124, 125, 127, 129, 131, 133, 135, 140, 143, 145, 146, 147, 153, 155, 162, 164, 165, 166, 169, 170, 173, 174, 176, 182, 185, 186, 188, 191, 204, 207, 213, 214, 216, 218, 220, 224, 225, 226, 227, 237, 240, 242, 245, 248, 252, 253, 254, 256, 262, 266, 272, 273, 274, 277, 279, 284, 288, 294, 296, 299, 300, 301, 302, 307, 308, 313, 315, 318, 326, 331, 333, 339, 349, 355, 356, 360, 361, 362, 363, 366, 391, 403, 419, 423, 427, 430, 437, 448, 462, 471, 480, 482, 511, 550, 592]
# Initial Circles: 597
# Final Circles: 438
# Indexes: [1, 3, 4, 5, 6, 8, 9, 11, 14, 15, 16, 18, 19, 20, 22, 24, 25, 27, 29, 30, 31, 32, 33, 34, 37, 40, 42, 43, 44, 46, 50, 51, 52, 53, 56, 58, 63, 65, 70, 74, 76, 77, 83, 84, 86, 89, 90, 91, 96, 97, 98, 99, 100, 102, 105, 106, 109, 111, 112, 114, 115, 122, 127, 128, 129, 131, 133, 137, 140, 142, 143, 144, 146, 148, 149, 155, 157, 160, 161, 162, 164, 167, 181, 183, 187, 190, 191, 195, 198, 199, 207, 211, 215, 217, 222, 223, 226, 233, 236, 238, 239, 243, 244, 250, 255, 256, 268, 271, 272, 277, 278, 280, 282, 283, 284, 293, 295, 298, 303, 304, 306, 313, 314, 316, 319, 324, 325, 326, 333, 338, 340, 341, 342, 346, 348, 349, 356, 358, 360, 371, 381, 388, 391, 393, 413, 420, 422, 434, 444, 453, 455, 475, 476, 487, 493, 545, 550, 555, 568]
# Initial Circles: 597
# Final Circles: 430
# Indexes: [0, 2, 3, 4, 5, 7, 8, 10, 11, 12, 13, 14, 20, 21, 22, 23, 26, 28, 29, 31, 32, 33, 35, 36, 37, 40, 41, 42, 44, 47, 48, 49, 50, 51, 52, 54, 56, 58, 60, 61, 63, 64, 66, 67, 69, 72, 73, 82, 83, 84, 85, 87, 88, 89, 91, 97, 98, 99, 101, 102, 107, 108, 109, 110, 111, 112, 113, 114, 117, 118, 119, 120, 121, 122, 124, 125, 129, 131, 133, 134, 137, 138, 141, 148, 149, 151, 152, 155, 156, 157, 160, 161, 166, 167, 170, 175, 180, 188, 192, 195, 197, 198, 205, 206, 207, 208, 210, 211, 216, 217, 219, 220, 223, 230, 234, 237, 239, 242, 245, 249, 250, 256, 258, 269, 271, 273, 275, 279, 284, 288, 289, 290, 291, 296, 297, 308, 329, 335, 340, 341, 343, 349, 351, 353, 360, 381, 383, 390, 402, 406, 412, 413, 415, 421, 427, 432, 448, 460, 461, 466, 484, 492, 504, 513, 526, 527, 579]
# CPU times: user 10.9 s, sys: 63.5 ms, total: 10.9 s
# Wall time: 11 s
